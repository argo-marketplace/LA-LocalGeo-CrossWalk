# %%
import pandas as pd

# %%
data = pd.read_csv('https://s3.amazonaws.com/argodata/result.csv')
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   repo_dist_                repo_dis_1        coun_comm_ precinct_n  \
# 0       0282  East Los Angeles Sheriff  East Los Angeles   4500090F
# 1       1625      Monterey Park Police  East Los Angeles   4500090F
# 2       0282  East Los Angeles Sheriff     Monterey Park   4500090F
# 3       1625      Monterey Park Police     Monterey Park   4500090F
# 4       0282  East Los Angeles Sheriff  East Los Angeles   2000062D
#
#    congress_d  senate_dis  assembly_d  community_        communit_1  area_num  \
# 0        27.0        22.0        49.0       450.0     MONTEREY PARK     828.0
# 1        27.0        22.0        49.0       450.0     MONTEREY PARK     828.0
# 2        27.0        22.0        49.0       450.0     MONTEREY PARK     828.0
# 3        27.0        22.0        49.0       450.0     MONTEREY PARK     828.0
# 4        40.0        24.0        51.0       200.0  EAST LOS ANGELES     811.0
#
#      ...    census_tra block_grou  census_blo    FIP           city  zip_code  \
# ...

# %%
data.to_csv('result.csv')

# %%
import csv
import json

csvfile = open('result.csv', 'r')
jsonfile = open('dummy.json', 'w')

reader = csv.DictReader( csvfile, data.columns)
out = json.dumps( [ row for row in reader ] )
jsonfile.write('{"geowalk" :' + (out) + '}')
# Out:
# 253136805

# %%
from __future__ import print_function
import pylab as pl
import os
import json
import sys
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

# %%
url = 'https://s3.amazonaws.com/argodata/dummy.json'

# %%
response = urllib.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)

# %%
data
# Out:
# [{'FIP': '48914',
#   'PUMA': '03737',
#   'area_name': 'SAN GABRIEL AREA',
#   'area_num': '828.000000000000000',
#   'assembly_d': '49.000000000000000',
#   'block_grou': '5304002',
#   'census_blo': '2038',
#   'census_tra': '530400',
#   'city': 'Monterey Park',
#   'communit_1': 'MONTEREY PARK',
#   'community_': '450.000000000000000',
#   'congress_d': '27.000000000000000',
#   'coun_comm_': 'East Los Angeles',
#   'health_d_1': 'East LA',
#   'health_dis': '16',
#   'precinct_1': 'MONTEREY PARK',
#   'precinct_n': '4500090F',
#   'repo_dis_1': 'East Los Angeles Sheriff',
#   'repo_dist_': '0282',
#   'senate_dis': '22.000000000000000',
#   'sup_dist': '1',
#   'zip_code': '90022'},
#  {'FIP': '48914',
#   'PUMA': '03737',
#   'area_name': 'SAN GABRIEL AREA',
#   'area_num': '828.000000000000000',
#   'assembly_d': '49.000000000000000',
#   'block_grou': '5304002',
#   'census_blo': '2038',
#   'census_tra': '530400',
#   'city': 'Monterey Park',
# ...
